# %%
from companykg import CompanyKG

# %% [markdown]
# ## Initialize CompanyKG

# %%
DATA_ROOT_FOLDER = "./data"

# It may take long time if the data files are not yet downloaded.
comkg = CompanyKG(nodes_feature_type="msbert", load_edges_weights=True, data_root_folder=DATA_ROOT_FOLDER)

# %%
# Obtain the list of node IDs using nodes_id
len(comkg.nodes_id)
# Out:
# 1169931

# %% [markdown]
# ## Inspect CompanyKG

# %%
# Show the important info of the loaded data
comkg.describe()
# Out:
# data_root_folder=./data
# n_nodes=1169931, n_edges=50815503
# nodes_feature_type=msbert
# nodes_feature_dimension=512
# edges_weight_dimension=15
# sp: 1764 samples
# sr: 1856 samples
# cr: 400 samples
# ep: 40000 samples

# %%
# Nodes feature: ordered by comkg.nodes_id
comkg.nodes_feature
# Out:
# tensor([[ 0.0642,  0.0100, -0.0427,  ...,  0.0580,  0.0156, -0.0645],
#         [ 0.0563, -0.0086, -0.0114,  ..., -0.0381, -0.0020, -0.1615],
#         [ 0.0668, -0.0803,  0.0296,  ...,  0.0003,  0.0872, -0.0662],
#         ...,
#         [-0.0072,  0.0593, -0.0401,  ...,  0.0861,  0.0681, -0.0302],
#         [-0.0445, -0.1243,  0.0048,  ...,  0.0149, -0.0466, -0.0800],
#         [-0.0396, -0.0113, -0.0121,  ..., -0.0240, -0.0342, -0.0039]])

# %%
# Edges
comkg.edges
# Out:
# tensor([[ 113091,  412357],
#         [ 560244, 1164306],
#         [ 388246, 1121544],
#         ...,
#         [  84160,  837013],
#         [ 179090,  917143],
#         [ 179090,  226260]])

# %%
# Edges weight
comkg.edges_weight
# Out:
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.7918],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.7918],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.7918],
#         ...,
#         [1.0000, 0.0000, 1.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [1.0000, 1.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [1.0000, 1.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]])

# %% [markdown]
# ## Inspect Evaluation Data

# %%
# SP samples
comkg.eval_tasks['sp'][1]
# Out:
#       node_id0  node_id1  label
# 0      1070786    136969      0
# 1       606364    184359      0
# 2         3848    223709      1
# 3       876994    242417      0
# 4       574071    242417      0
# ...        ...       ...    ...
# 1759    771712   1027754      1
# 1760   1114431   1046037      0
# 1761    247018   1046339      0
# 1762     98621   1168288      1
# 1763    247434   1168288      1
#
# [1764 rows x 3 columns]

# %%
# SR samples
comkg.eval_tasks['sr'][1]
# Out:
#       target_node_id  candidate0_node_id  candidate1_node_id  label
# 0             201389              198435              797652      0  \
# 1             450703              618486              624384      0
# 2            1097415              297978              386584      0
# 3              81000              244410             1016534      0
# 4             861572             1155658             1115208      0
# ...              ...                 ...                 ...    ...
# 1851          522257              669089              607981      1
# 1852         1083662              203070              482478      1
# 1853          354276              551887              865995      0
# 1854          830672              504882             1046882      1
# 1855          804707              991173               91744      1
#
#            split
# 0           test
# 1           test
# 2     validation
# 3           test
# 4           test
# ...          ...
# 1851        test
# 1852  validation
# 1853        test
# 1854        test
# 1855        test
#
# [1856 rows x 5 columns]

# %%
# CR samples
comkg.eval_tasks['cr'][1]
# Out:
#      target_node_id  competitor_node_id
# 0              3843               34994
# 1              3843              263332
# 2              3843             1034500
# 3              4981               45823
# 4              4981              288480
# ..              ...                 ...
# 395         1144634             1004440
# 396         1144634             1077443
# 397         1163522              172921
# 398         1163522              268689
# 399         1163522             1149354
#
# [400 rows x 2 columns]

# %%
# EP samples
comkg.eval_tasks['ep'][1]
# Out:
#        node_id0  node_id1  et2  et3  et4  et5  et8  et10  et14  et15
# 0        217024    716915    0    0    0    0    0     0     0     1  \
# 1        435690    994558    0    0    0    0    0     1     0     0
# 2         78531    691964    0    0    0    0    0     0     0     1
# 3        457175    456862    0    0    0    1    0     0     0     0
# 4        430325     84446    0    0    0    1    0     0     0     0
# ...         ...       ...  ...  ...  ...  ...  ...   ...   ...   ...
# 39995     89061    609621    0    0    0    0    0     0     1     0
# 39996    197242    938619    0    0    0    0    0     0     1     0
# 39997    367197    465661    0    0    0    0    1     0     0     0
# 39998    597795    668947    0    0    0    0    0     1     0     0
# 39999    229573   1160714    0    0    0    0    0     1     0     0
#
#             split
# 0            test
# 1            test
# 2            test
# 3            test
# 4      validation
# ...           ...
# 39995        test
# 39996        test
# 39997        test
# 39998        test
# 39999        test
#
# [40000 rows x 11 columns]

# %% [markdown]
# ## Evaluate Node Feature

# %%
# Run all evaluation tasks on the loaded node feature
eval_results = comkg.evaluate()
# Out:
# Evaluate Node Features msbert:
# Evaluate SP ...
# SP AUC: 0.7519511905744471
# Evaluate SR ...
# SR Validation ACC: 0.6956521739130435 SR Test ACC: 0.6713709677419355
# Evaluate CR with top-K hit rate (K=[50, 100, 200, 500, 1000, 2000, 5000, 10000]) ...
# CR Hit Rates: [0.12955922001974632, 0.18240535049745576, 0.23030967570441258, 0.31102329687856, 0.4143004291030607, 0.47711466165413524, 0.5583993126756285, 0.6349049707602339]
# Evaluate EP ...
# Trial 1
# Using device: cuda
# Epoch [1/100], Validation Loss: 1.6778, Overall Validation AUC-ROC: 0.7937
# Class 0 Validation AUC-ROC: 0.7330
# Class 1 Validation AUC-ROC: 0.7873
# Class 2 Validation AUC-ROC: 0.7210
# Class 3 Validation AUC-ROC: 0.9202
# Class 4 Validation AUC-ROC: 0.9213
# Class 5 Validation AUC-ROC: 0.7016
# Class 6 Validation AUC-ROC: 0.7607
# Class 7 Validation AUC-ROC: 0.8045
# Epoch [2/100], Validation Loss: 1.6365, Overall Validation AUC-ROC: 0.8086
# Class 0 Validation AUC-ROC: 0.7586
# Class 1 Validation AUC-ROC: 0.7993
# Class 2 Validation AUC-ROC: 0.7397
# Class 3 Validation AUC-ROC: 0.9284
# Class 4 Validation AUC-ROC: 0.9282
# Class 5 Validation AUC-ROC: 0.7408
# Class 6 Validation AUC-ROC: 0.7614
# Class 7 Validation AUC-ROC: 0.8124
# Epoch [3/100], Validation Loss: 1.6515, Overall Validation AUC-ROC: 0.8157
# Class 0 Validation AUC-ROC: 0.7612
# Class 1 Validation AUC-ROC: 0.8109
# Class 2 Validation AUC-ROC: 0.7523
# Class 3 Validation AUC-ROC: 0.9296
# Class 4 Validation AUC-ROC: 0.9299
# Class 5 Validation AUC-ROC: 0.7551
# Class 6 Validation AUC-ROC: 0.7688
# Class 7 Validation AUC-ROC: 0.8177
# Epoch [4/100], Validation Loss: 1.7310, Overall Validation AUC-ROC: 0.8110
# Class 0 Validation AUC-ROC: 0.7383
# Class 1 Validation AUC-ROC: 0.7991
# Class 2 Validation AUC-ROC: 0.7542
# Class 3 Validation AUC-ROC: 0.9301
# Class 4 Validation AUC-ROC: 0.9307
# Class 5 Validation AUC-ROC: 0.7485
# Class 6 Validation AUC-ROC: 0.7767
# Class 7 Validation AUC-ROC: 0.8103
# Epoch [5/100], Validation Loss: 1.7539, Overall Validation AUC-ROC: 0.8121
# Class 0 Validation AUC-ROC: 0.7513
# Class 1 Validation AUC-ROC: 0.7999
# Class 2 Validation AUC-ROC: 0.7579
# Class 3 Validation AUC-ROC: 0.9300
# Class 4 Validation AUC-ROC: 0.9317
# Class 5 Validation AUC-ROC: 0.7501
# Class 6 Validation AUC-ROC: 0.7736
# Class 7 Validation AUC-ROC: 0.8026
# Epoch [6/100], Validation Loss: 1.8129, Overall Validation AUC-ROC: 0.8138
# Class 0 Validation AUC-ROC: 0.7530
# Class 1 Validation AUC-ROC: 0.8016
# Class 2 Validation AUC-ROC: 0.7584
# Class 3 Validation AUC-ROC: 0.9280
# Class 4 Validation AUC-ROC: 0.9323
# Class 5 Validation AUC-ROC: 0.7542
# Class 6 Validation AUC-ROC: 0.7780
# Class 7 Validation AUC-ROC: 0.8049
# Epoch [7/100], Validation Loss: 1.8804, Overall Validation AUC-ROC: 0.8123
# Class 0 Validation AUC-ROC: 0.7526
# Class 1 Validation AUC-ROC: 0.7965
# Class 2 Validation AUC-ROC: 0.7659
# Class 3 Validation AUC-ROC: 0.9243
# Class 4 Validation AUC-ROC: 0.9348
# Class 5 Validation AUC-ROC: 0.7408
# Class 6 Validation AUC-ROC: 0.7860
# Class 7 Validation AUC-ROC: 0.7972
# Epoch [8/100], Validation Loss: 1.8171, Overall Validation AUC-ROC: 0.8154
# Class 0 Validation AUC-ROC: 0.7495
# Class 1 Validation AUC-ROC: 0.8049
# Class 2 Validation AUC-ROC: 0.7578
# Class 3 Validation AUC-ROC: 0.9248
# Class 4 Validation AUC-ROC: 0.9331
# Class 5 Validation AUC-ROC: 0.7640
# Class 6 Validation AUC-ROC: 0.7842
# Class 7 Validation AUC-ROC: 0.8050
# Early stopping
# Overall Test AUC-ROC: 0.8168
# Class 0 Test AUC-ROC: 0.7522
# Class 1 Test AUC-ROC: 0.8138
# Class 2 Test AUC-ROC: 0.7549
# Class 3 Test AUC-ROC: 0.9255
# Class 4 Test AUC-ROC: 0.9265
# Class 5 Test AUC-ROC: 0.7592
# Class 6 Test AUC-ROC: 0.7869
# Class 7 Test AUC-ROC: 0.8157
# Trial 2
# Using device: cuda
# Epoch [1/100], Validation Loss: 1.6618, Overall Validation AUC-ROC: 0.7958
# Class 0 Validation AUC-ROC: 0.7595
# Class 1 Validation AUC-ROC: 0.7684
# Class 2 Validation AUC-ROC: 0.7144
# Class 3 Validation AUC-ROC: 0.9257
# Class 4 Validation AUC-ROC: 0.9206
# Class 5 Validation AUC-ROC: 0.7019
# Class 6 Validation AUC-ROC: 0.7653
# Class 7 Validation AUC-ROC: 0.8108
# Epoch [2/100], Validation Loss: 1.6329, Overall Validation AUC-ROC: 0.8122
# Class 0 Validation AUC-ROC: 0.7874
# Class 1 Validation AUC-ROC: 0.8075
# Class 2 Validation AUC-ROC: 0.7320
# Class 3 Validation AUC-ROC: 0.9242
# Class 4 Validation AUC-ROC: 0.9255
# Class 5 Validation AUC-ROC: 0.7348
# Class 6 Validation AUC-ROC: 0.7766
# Class 7 Validation AUC-ROC: 0.8093
# Epoch [3/100], Validation Loss: 1.6607, Overall Validation AUC-ROC: 0.8149
# Class 0 Validation AUC-ROC: 0.7724
# Class 1 Validation AUC-ROC: 0.8039
# Class 2 Validation AUC-ROC: 0.7491
# Class 3 Validation AUC-ROC: 0.9304
# Class 4 Validation AUC-ROC: 0.9280
# Class 5 Validation AUC-ROC: 0.7374
# Class 6 Validation AUC-ROC: 0.7807
# Class 7 Validation AUC-ROC: 0.8174
# Epoch [4/100], Validation Loss: 1.7669, Overall Validation AUC-ROC: 0.8121
# Class 0 Validation AUC-ROC: 0.7354
# Class 1 Validation AUC-ROC: 0.8112
# Class 2 Validation AUC-ROC: 0.7547
# Class 3 Validation AUC-ROC: 0.9309
# Class 4 Validation AUC-ROC: 0.9313
# Class 5 Validation AUC-ROC: 0.7470
# Class 6 Validation AUC-ROC: 0.7841
# Class 7 Validation AUC-ROC: 0.8026
# Epoch [5/100], Validation Loss: 1.7384, Overall Validation AUC-ROC: 0.8164
# Class 0 Validation AUC-ROC: 0.7690
# Class 1 Validation AUC-ROC: 0.8067
# Class 2 Validation AUC-ROC: 0.7564
# Class 3 Validation AUC-ROC: 0.9322
# Class 4 Validation AUC-ROC: 0.9321
# Class 5 Validation AUC-ROC: 0.7474
# Class 6 Validation AUC-ROC: 0.7802
# Class 7 Validation AUC-ROC: 0.8075
# Epoch [6/100], Validation Loss: 1.8705, Overall Validation AUC-ROC: 0.8162
# Class 0 Validation AUC-ROC: 0.7454
# Class 1 Validation AUC-ROC: 0.8155
# Class 2 Validation AUC-ROC: 0.7538
# Class 3 Validation AUC-ROC: 0.9308
# Class 4 Validation AUC-ROC: 0.9320
# Class 5 Validation AUC-ROC: 0.7514
# Class 6 Validation AUC-ROC: 0.7887
# Class 7 Validation AUC-ROC: 0.8117
# Epoch [7/100], Validation Loss: 1.8047, Overall Validation AUC-ROC: 0.8166
# Class 0 Validation AUC-ROC: 0.7487
# Class 1 Validation AUC-ROC: 0.8195
# Class 2 Validation AUC-ROC: 0.7590
# Class 3 Validation AUC-ROC: 0.9294
# Class 4 Validation AUC-ROC: 0.9327
# Class 5 Validation AUC-ROC: 0.7489
# Class 6 Validation AUC-ROC: 0.7860
# Class 7 Validation AUC-ROC: 0.8087
# Epoch [8/100], Validation Loss: 1.8477, Overall Validation AUC-ROC: 0.8189
# Class 0 Validation AUC-ROC: 0.7595
# Class 1 Validation AUC-ROC: 0.8198
# Class 2 Validation AUC-ROC: 0.7555
# Class 3 Validation AUC-ROC: 0.9295
# Class 4 Validation AUC-ROC: 0.9323
# Class 5 Validation AUC-ROC: 0.7566
# Class 6 Validation AUC-ROC: 0.7910
# Class 7 Validation AUC-ROC: 0.8070
# Epoch [9/100], Validation Loss: 1.9086, Overall Validation AUC-ROC: 0.8149
# Class 0 Validation AUC-ROC: 0.7225
# Class 1 Validation AUC-ROC: 0.8148
# Class 2 Validation AUC-ROC: 0.7615
# Class 3 Validation AUC-ROC: 0.9321
# Class 4 Validation AUC-ROC: 0.9330
# Class 5 Validation AUC-ROC: 0.7589
# Class 6 Validation AUC-ROC: 0.7892
# Class 7 Validation AUC-ROC: 0.8074
# Epoch [10/100], Validation Loss: 1.9392, Overall Validation AUC-ROC: 0.8154
# Class 0 Validation AUC-ROC: 0.7433
# Class 1 Validation AUC-ROC: 0.8077
# Class 2 Validation AUC-ROC: 0.7557
# Class 3 Validation AUC-ROC: 0.9318
# Class 4 Validation AUC-ROC: 0.9312
# Class 5 Validation AUC-ROC: 0.7584
# Class 6 Validation AUC-ROC: 0.7901
# Class 7 Validation AUC-ROC: 0.8050
# Epoch [11/100], Validation Loss: 2.0525, Overall Validation AUC-ROC: 0.8159
# Class 0 Validation AUC-ROC: 0.7491
# Class 1 Validation AUC-ROC: 0.8100
# Class 2 Validation AUC-ROC: 0.7576
# Class 3 Validation AUC-ROC: 0.9305
# Class 4 Validation AUC-ROC: 0.9321
# Class 5 Validation AUC-ROC: 0.7569
# Class 6 Validation AUC-ROC: 0.7911
# Class 7 Validation AUC-ROC: 0.8003
# Epoch [12/100], Validation Loss: 2.0090, Overall Validation AUC-ROC: 0.8140
# Class 0 Validation AUC-ROC: 0.7511
# Class 1 Validation AUC-ROC: 0.8003
# Class 2 Validation AUC-ROC: 0.7505
# Class 3 Validation AUC-ROC: 0.9312
# Class 4 Validation AUC-ROC: 0.9321
# Class 5 Validation AUC-ROC: 0.7539
# Class 6 Validation AUC-ROC: 0.7897
# Class 7 Validation AUC-ROC: 0.8032
# Epoch [13/100], Validation Loss: 2.0587, Overall Validation AUC-ROC: 0.8128
# Class 0 Validation AUC-ROC: 0.7507
# Class 1 Validation AUC-ROC: 0.8053
# Class 2 Validation AUC-ROC: 0.7531
# Class 3 Validation AUC-ROC: 0.9307
# Class 4 Validation AUC-ROC: 0.9332
# Class 5 Validation AUC-ROC: 0.7477
# Class 6 Validation AUC-ROC: 0.7856
# Class 7 Validation AUC-ROC: 0.7963
# Early stopping
# Overall Test AUC-ROC: 0.8144
# Class 0 Test AUC-ROC: 0.7553
# Class 1 Test AUC-ROC: 0.8073
# Class 2 Test AUC-ROC: 0.7512
# Class 3 Test AUC-ROC: 0.9312
# Class 4 Test AUC-ROC: 0.9276
# Class 5 Test AUC-ROC: 0.7475
# Class 6 Test AUC-ROC: 0.7929
# Class 7 Test AUC-ROC: 0.8022
# Trial 3
# Using device: cuda
# Epoch [1/100], Validation Loss: 1.6053, Overall Validation AUC-ROC: 0.8030
# Class 0 Validation AUC-ROC: 0.7871
# Class 1 Validation AUC-ROC: 0.7937
# Class 2 Validation AUC-ROC: 0.7341
# Class 3 Validation AUC-ROC: 0.9211
# Class 4 Validation AUC-ROC: 0.9136
# Class 5 Validation AUC-ROC: 0.7009
# Class 6 Validation AUC-ROC: 0.7583
# Class 7 Validation AUC-ROC: 0.8147
# Epoch [2/100], Validation Loss: 1.6464, Overall Validation AUC-ROC: 0.8067
# Class 0 Validation AUC-ROC: 0.7587
# Class 1 Validation AUC-ROC: 0.8023
# Class 2 Validation AUC-ROC: 0.7403
# Class 3 Validation AUC-ROC: 0.9257
# Class 4 Validation AUC-ROC: 0.9243
# Class 5 Validation AUC-ROC: 0.7216
# Class 6 Validation AUC-ROC: 0.7665
# Class 7 Validation AUC-ROC: 0.8141
# Epoch [3/100], Validation Loss: 1.6628, Overall Validation AUC-ROC: 0.8158
# Class 0 Validation AUC-ROC: 0.7654
# Class 1 Validation AUC-ROC: 0.8260
# Class 2 Validation AUC-ROC: 0.7527
# Class 3 Validation AUC-ROC: 0.9304
# Class 4 Validation AUC-ROC: 0.9291
# Class 5 Validation AUC-ROC: 0.7499
# Class 6 Validation AUC-ROC: 0.7646
# Class 7 Validation AUC-ROC: 0.8086
# Epoch [4/100], Validation Loss: 1.7219, Overall Validation AUC-ROC: 0.8156
# Class 0 Validation AUC-ROC: 0.7543
# Class 1 Validation AUC-ROC: 0.8100
# Class 2 Validation AUC-ROC: 0.7583
# Class 3 Validation AUC-ROC: 0.9314
# Class 4 Validation AUC-ROC: 0.9287
# Class 5 Validation AUC-ROC: 0.7648
# Class 6 Validation AUC-ROC: 0.7709
# Class 7 Validation AUC-ROC: 0.8062
# Epoch [5/100], Validation Loss: 1.7608, Overall Validation AUC-ROC: 0.8130
# Class 0 Validation AUC-ROC: 0.7469
# Class 1 Validation AUC-ROC: 0.8043
# Class 2 Validation AUC-ROC: 0.7564
# Class 3 Validation AUC-ROC: 0.9243
# Class 4 Validation AUC-ROC: 0.9296
# Class 5 Validation AUC-ROC: 0.7584
# Class 6 Validation AUC-ROC: 0.7777
# Class 7 Validation AUC-ROC: 0.8062
# Epoch [6/100], Validation Loss: 1.7809, Overall Validation AUC-ROC: 0.8156
# Class 0 Validation AUC-ROC: 0.7500
# Class 1 Validation AUC-ROC: 0.8023
# Class 2 Validation AUC-ROC: 0.7589
# Class 3 Validation AUC-ROC: 0.9320
# Class 4 Validation AUC-ROC: 0.9324
# Class 5 Validation AUC-ROC: 0.7625
# Class 6 Validation AUC-ROC: 0.7812
# Class 7 Validation AUC-ROC: 0.8053
# Epoch [7/100], Validation Loss: 1.9351, Overall Validation AUC-ROC: 0.8080
# Class 0 Validation AUC-ROC: 0.6931
# Class 1 Validation AUC-ROC: 0.8311
# Class 2 Validation AUC-ROC: 0.7568
# Class 3 Validation AUC-ROC: 0.9296
# Class 4 Validation AUC-ROC: 0.9314
# Class 5 Validation AUC-ROC: 0.7432
# Class 6 Validation AUC-ROC: 0.7752
# Class 7 Validation AUC-ROC: 0.8039
# Epoch [8/100], Validation Loss: 1.8776, Overall Validation AUC-ROC: 0.8128
# Class 0 Validation AUC-ROC: 0.7404
# Class 1 Validation AUC-ROC: 0.8157
# Class 2 Validation AUC-ROC: 0.7567
# Class 3 Validation AUC-ROC: 0.9248
# Class 4 Validation AUC-ROC: 0.9319
# Class 5 Validation AUC-ROC: 0.7501
# Class 6 Validation AUC-ROC: 0.7839
# Class 7 Validation AUC-ROC: 0.7992
# Early stopping
# Overall Test AUC-ROC: 0.8146
# Class 0 Test AUC-ROC: 0.7442
# Class 1 Test AUC-ROC: 0.8236
# Class 2 Test AUC-ROC: 0.7555
# Class 3 Test AUC-ROC: 0.9237
# Class 4 Test AUC-ROC: 0.9258
# Class 5 Test AUC-ROC: 0.7447
# Class 6 Test AUC-ROC: 0.7888
# Class 7 Test AUC-ROC: 0.8102

# %%
# Show AUC score for SP task
eval_results["sp_auc"]
# Out:
# 0.7519511905744471

# %%
# Show test accuracy for SR task
eval_results["sr_test_acc"]
# Out:
# 0.6713709677419355

# %%
# Show validation accuracy for SR task
eval_results["sr_validation_acc"]
# Out:
# 0.6956521739130435

# %%
# Show Top-K Hit Rate for CR task
eval_results["cr_topk_hit_rate"]
# Out:
# [0.12955922001974632,
#  0.18240535049745576,
#  0.23030967570441258,
#  0.31102329687856,
#  0.4143004291030607,
#  0.47711466165413524,
#  0.5583993126756285,
#  0.6349049707602339]

# %%
# Show overall AUC and per-ET AUC for EP task from all trials
eval_results["ep_test_auc"]
# Out:
# {'overall_mean': 0.8152710799319728,
#  'overall_std': 0.0011013208302879237,
#  'per_class_mean': array([0.75057417, 0.8148841 , 0.75387312, 0.92682654, 0.92663642,
#         0.75045155, 0.78954263, 0.80938012]),
#  'per_class_std': array([0.00467002, 0.00671789, 0.00189928, 0.00319254, 0.00073781,
#         0.00627061, 0.00250782, 0.00553296]),
#  'test_auc_scores': [{'overall_test_auc': 0.8168251581632653,
#    'per_class_test_auc': array([0.75219244, 0.81377389, 0.75488691, 0.92551108, 0.92647168,
#           0.75917381, 0.78688562, 0.81570583])},
#   {'overall_test_auc': 0.8144046428571429,
#    'per_class_test_auc': array([0.75531024, 0.80726787, 0.75121214, 0.93122468, 0.92761108,
#           0.74747696, 0.79290557, 0.80222859])},
#   {'overall_test_auc': 0.8145834387755102,
#    'per_class_test_auc': array([0.74421981, 0.82361053, 0.75552031, 0.92374386, 0.9258265 ,
#           0.74470388, 0.78883669, 0.81020594])}]}

# %% [markdown]
# ## Evaluate Saved Embedding

# %%
# Run all evaluation tasks on the specified embeddings saved in torch.Tensor format

EMBEDDINGS_FILE = "./data/nodes_feature_msbert.pt"

eval_results = comkg.evaluate(embeddings_file=EMBEDDINGS_FILE)
# Out:
# Evaluate Node Embeddings ./data/nodes_feature_msbert.pt:
# Evaluate SP ...
# SP AUC: 0.7519511905744471
# Evaluate SR ...
# SR Validation ACC: 0.6956521739130435 SR Test ACC: 0.6713709677419355
# Evaluate CR with top-K hit rate (K=[50, 100, 200, 500, 1000, 2000, 5000, 10000]) ...
# CR Hit Rates: [0.12955922001974632, 0.18240535049745576, 0.23030967570441258, 0.31102329687856, 0.4143004291030607, 0.47711466165413524, 0.5583993126756285, 0.6349049707602339]
# Evaluate EP ...
# Trial 1
# Using device: cuda
# Epoch [1/100], Validation Loss: 1.6720, Overall Validation AUC-ROC: 0.7911
# Class 0 Validation AUC-ROC: 0.7555
# Class 1 Validation AUC-ROC: 0.7570
# Class 2 Validation AUC-ROC: 0.7154
# Class 3 Validation AUC-ROC: 0.9259
# Class 4 Validation AUC-ROC: 0.9210
# Class 5 Validation AUC-ROC: 0.6953
# Class 6 Validation AUC-ROC: 0.7547
# Class 7 Validation AUC-ROC: 0.8044
# Epoch [2/100], Validation Loss: 1.7054, Overall Validation AUC-ROC: 0.8080
# Class 0 Validation AUC-ROC: 0.7765
# Class 1 Validation AUC-ROC: 0.7904
# Class 2 Validation AUC-ROC: 0.7409
# Class 3 Validation AUC-ROC: 0.9278
# Class 4 Validation AUC-ROC: 0.9256
# Class 5 Validation AUC-ROC: 0.7191
# Class 6 Validation AUC-ROC: 0.7755
# Class 7 Validation AUC-ROC: 0.8080
# Epoch [3/100], Validation Loss: 1.6955, Overall Validation AUC-ROC: 0.8085
# Class 0 Validation AUC-ROC: 0.7383
# Class 1 Validation AUC-ROC: 0.7948
# Class 2 Validation AUC-ROC: 0.7531
# Class 3 Validation AUC-ROC: 0.9318
# Class 4 Validation AUC-ROC: 0.9279
# Class 5 Validation AUC-ROC: 0.7455
# Class 6 Validation AUC-ROC: 0.7740
# Class 7 Validation AUC-ROC: 0.8028
# Epoch [4/100], Validation Loss: 1.6924, Overall Validation AUC-ROC: 0.8173
# Class 0 Validation AUC-ROC: 0.7631
# Class 1 Validation AUC-ROC: 0.8086
# Class 2 Validation AUC-ROC: 0.7526
# Class 3 Validation AUC-ROC: 0.9354
# Class 4 Validation AUC-ROC: 0.9320
# Class 5 Validation AUC-ROC: 0.7572
# Class 6 Validation AUC-ROC: 0.7792
# Class 7 Validation AUC-ROC: 0.8103
# Epoch [5/100], Validation Loss: 1.7904, Overall Validation AUC-ROC: 0.8126
# Class 0 Validation AUC-ROC: 0.7427
# Class 1 Validation AUC-ROC: 0.8121
# Class 2 Validation AUC-ROC: 0.7512
# Class 3 Validation AUC-ROC: 0.9304
# Class 4 Validation AUC-ROC: 0.9327
# Class 5 Validation AUC-ROC: 0.7467
# Class 6 Validation AUC-ROC: 0.7811
# Class 7 Validation AUC-ROC: 0.8040
# Epoch [6/100], Validation Loss: 1.8020, Overall Validation AUC-ROC: 0.8161
# Class 0 Validation AUC-ROC: 0.7518
# Class 1 Validation AUC-ROC: 0.8053
# Class 2 Validation AUC-ROC: 0.7684
# Class 3 Validation AUC-ROC: 0.9350
# Class 4 Validation AUC-ROC: 0.9332
# Class 5 Validation AUC-ROC: 0.7492
# Class 6 Validation AUC-ROC: 0.7836
# Class 7 Validation AUC-ROC: 0.8020
# Epoch [7/100], Validation Loss: 1.8538, Overall Validation AUC-ROC: 0.8148
# Class 0 Validation AUC-ROC: 0.7488
# Class 1 Validation AUC-ROC: 0.7971
# Class 2 Validation AUC-ROC: 0.7614
# Class 3 Validation AUC-ROC: 0.9336
# Class 4 Validation AUC-ROC: 0.9335
# Class 5 Validation AUC-ROC: 0.7581
# Class 6 Validation AUC-ROC: 0.7818
# Class 7 Validation AUC-ROC: 0.8040
# Epoch [8/100], Validation Loss: 1.8530, Overall Validation AUC-ROC: 0.8166
# Class 0 Validation AUC-ROC: 0.7582
# Class 1 Validation AUC-ROC: 0.7904
# Class 2 Validation AUC-ROC: 0.7583
# Class 3 Validation AUC-ROC: 0.9333
# Class 4 Validation AUC-ROC: 0.9346
# Class 5 Validation AUC-ROC: 0.7715
# Class 6 Validation AUC-ROC: 0.7806
# Class 7 Validation AUC-ROC: 0.8061
# Epoch [9/100], Validation Loss: 1.8952, Overall Validation AUC-ROC: 0.8185
# Class 0 Validation AUC-ROC: 0.7765
# Class 1 Validation AUC-ROC: 0.8002
# Class 2 Validation AUC-ROC: 0.7618
# Class 3 Validation AUC-ROC: 0.9336
# Class 4 Validation AUC-ROC: 0.9334
# Class 5 Validation AUC-ROC: 0.7534
# Class 6 Validation AUC-ROC: 0.7881
# Class 7 Validation AUC-ROC: 0.8007
# Epoch [10/100], Validation Loss: 1.9547, Overall Validation AUC-ROC: 0.8144
# Class 0 Validation AUC-ROC: 0.7573
# Class 1 Validation AUC-ROC: 0.7908
# Class 2 Validation AUC-ROC: 0.7568
# Class 3 Validation AUC-ROC: 0.9357
# Class 4 Validation AUC-ROC: 0.9346
# Class 5 Validation AUC-ROC: 0.7572
# Class 6 Validation AUC-ROC: 0.7815
# Class 7 Validation AUC-ROC: 0.8015
# Epoch [11/100], Validation Loss: 1.9540, Overall Validation AUC-ROC: 0.8172
# Class 0 Validation AUC-ROC: 0.7672
# Class 1 Validation AUC-ROC: 0.7969
# Class 2 Validation AUC-ROC: 0.7651
# Class 3 Validation AUC-ROC: 0.9380
# Class 4 Validation AUC-ROC: 0.9337
# Class 5 Validation AUC-ROC: 0.7592
# Class 6 Validation AUC-ROC: 0.7831
# Class 7 Validation AUC-ROC: 0.7942
# Epoch [12/100], Validation Loss: 2.0528, Overall Validation AUC-ROC: 0.8136
# Class 0 Validation AUC-ROC: 0.7398
# Class 1 Validation AUC-ROC: 0.8024
# Class 2 Validation AUC-ROC: 0.7604
# Class 3 Validation AUC-ROC: 0.9315
# Class 4 Validation AUC-ROC: 0.9332
# Class 5 Validation AUC-ROC: 0.7613
# Class 6 Validation AUC-ROC: 0.7852
# Class 7 Validation AUC-ROC: 0.7950
# Epoch [13/100], Validation Loss: 2.0235, Overall Validation AUC-ROC: 0.8135
# Class 0 Validation AUC-ROC: 0.7507
# Class 1 Validation AUC-ROC: 0.8022
# Class 2 Validation AUC-ROC: 0.7585
# Class 3 Validation AUC-ROC: 0.9315
# Class 4 Validation AUC-ROC: 0.9346
# Class 5 Validation AUC-ROC: 0.7596
# Class 6 Validation AUC-ROC: 0.7813
# Class 7 Validation AUC-ROC: 0.7897
# Epoch [14/100], Validation Loss: 2.0363, Overall Validation AUC-ROC: 0.8145
# Class 0 Validation AUC-ROC: 0.7461
# Class 1 Validation AUC-ROC: 0.7972
# Class 2 Validation AUC-ROC: 0.7587
# Class 3 Validation AUC-ROC: 0.9333
# Class 4 Validation AUC-ROC: 0.9339
# Class 5 Validation AUC-ROC: 0.7678
# Class 6 Validation AUC-ROC: 0.7871
# Class 7 Validation AUC-ROC: 0.7921
# Early stopping
# Overall Test AUC-ROC: 0.8140
# Class 0 Test AUC-ROC: 0.7416
# Class 1 Test AUC-ROC: 0.8084
# Class 2 Test AUC-ROC: 0.7584
# Class 3 Test AUC-ROC: 0.9283
# Class 4 Test AUC-ROC: 0.9264
# Class 5 Test AUC-ROC: 0.7646
# Class 6 Test AUC-ROC: 0.7860
# Class 7 Test AUC-ROC: 0.7979
# Trial 2
# Using device: cuda
# Epoch [1/100], Validation Loss: 1.6612, Overall Validation AUC-ROC: 0.7928
# Class 0 Validation AUC-ROC: 0.7425
# Class 1 Validation AUC-ROC: 0.7793
# Class 2 Validation AUC-ROC: 0.7135
# Class 3 Validation AUC-ROC: 0.9235
# Class 4 Validation AUC-ROC: 0.9179
# Class 5 Validation AUC-ROC: 0.7099
# Class 6 Validation AUC-ROC: 0.7484
# Class 7 Validation AUC-ROC: 0.8077
# Epoch [2/100], Validation Loss: 1.6565, Overall Validation AUC-ROC: 0.8070
# Class 0 Validation AUC-ROC: 0.7725
# Class 1 Validation AUC-ROC: 0.7730
# Class 2 Validation AUC-ROC: 0.7415
# Class 3 Validation AUC-ROC: 0.9258
# Class 4 Validation AUC-ROC: 0.9246
# Class 5 Validation AUC-ROC: 0.7356
# Class 6 Validation AUC-ROC: 0.7717
# Class 7 Validation AUC-ROC: 0.8114
# Epoch [3/100], Validation Loss: 1.6538, Overall Validation AUC-ROC: 0.8153
# Class 0 Validation AUC-ROC: 0.7692
# Class 1 Validation AUC-ROC: 0.8018
# Class 2 Validation AUC-ROC: 0.7529
# Class 3 Validation AUC-ROC: 0.9300
# Class 4 Validation AUC-ROC: 0.9299
# Class 5 Validation AUC-ROC: 0.7528
# Class 6 Validation AUC-ROC: 0.7692
# Class 7 Validation AUC-ROC: 0.8168
# Epoch [4/100], Validation Loss: 1.6969, Overall Validation AUC-ROC: 0.8160
# Class 0 Validation AUC-ROC: 0.7482
# Class 1 Validation AUC-ROC: 0.8182
# Class 2 Validation AUC-ROC: 0.7605
# Class 3 Validation AUC-ROC: 0.9306
# Class 4 Validation AUC-ROC: 0.9297
# Class 5 Validation AUC-ROC: 0.7508
# Class 6 Validation AUC-ROC: 0.7762
# Class 7 Validation AUC-ROC: 0.8140
# Epoch [5/100], Validation Loss: 1.7506, Overall Validation AUC-ROC: 0.8139
# Class 0 Validation AUC-ROC: 0.7563
# Class 1 Validation AUC-ROC: 0.8135
# Class 2 Validation AUC-ROC: 0.7565
# Class 3 Validation AUC-ROC: 0.9304
# Class 4 Validation AUC-ROC: 0.9312
# Class 5 Validation AUC-ROC: 0.7444
# Class 6 Validation AUC-ROC: 0.7756
# Class 7 Validation AUC-ROC: 0.8035
# Epoch [6/100], Validation Loss: 1.8429, Overall Validation AUC-ROC: 0.8127
# Class 0 Validation AUC-ROC: 0.7382
# Class 1 Validation AUC-ROC: 0.8138
# Class 2 Validation AUC-ROC: 0.7538
# Class 3 Validation AUC-ROC: 0.9313
# Class 4 Validation AUC-ROC: 0.9318
# Class 5 Validation AUC-ROC: 0.7444
# Class 6 Validation AUC-ROC: 0.7798
# Class 7 Validation AUC-ROC: 0.8087
# Epoch [7/100], Validation Loss: 1.7913, Overall Validation AUC-ROC: 0.8192
# Class 0 Validation AUC-ROC: 0.7699
# Class 1 Validation AUC-ROC: 0.8210
# Class 2 Validation AUC-ROC: 0.7535
# Class 3 Validation AUC-ROC: 0.9324
# Class 4 Validation AUC-ROC: 0.9313
# Class 5 Validation AUC-ROC: 0.7659
# Class 6 Validation AUC-ROC: 0.7761
# Class 7 Validation AUC-ROC: 0.8039
# Epoch [8/100], Validation Loss: 1.8995, Overall Validation AUC-ROC: 0.8157
# Class 0 Validation AUC-ROC: 0.7399
# Class 1 Validation AUC-ROC: 0.8240
# Class 2 Validation AUC-ROC: 0.7638
# Class 3 Validation AUC-ROC: 0.9300
# Class 4 Validation AUC-ROC: 0.9328
# Class 5 Validation AUC-ROC: 0.7612
# Class 6 Validation AUC-ROC: 0.7733
# Class 7 Validation AUC-ROC: 0.8004
# Epoch [9/100], Validation Loss: 1.8929, Overall Validation AUC-ROC: 0.8145
# Class 0 Validation AUC-ROC: 0.7451
# Class 1 Validation AUC-ROC: 0.8011
# Class 2 Validation AUC-ROC: 0.7604
# Class 3 Validation AUC-ROC: 0.9312
# Class 4 Validation AUC-ROC: 0.9311
# Class 5 Validation AUC-ROC: 0.7585
# Class 6 Validation AUC-ROC: 0.7792
# Class 7 Validation AUC-ROC: 0.8089
# Epoch [10/100], Validation Loss: 1.9159, Overall Validation AUC-ROC: 0.8148
# Class 0 Validation AUC-ROC: 0.7415
# Class 1 Validation AUC-ROC: 0.8152
# Class 2 Validation AUC-ROC: 0.7577
# Class 3 Validation AUC-ROC: 0.9242
# Class 4 Validation AUC-ROC: 0.9327
# Class 5 Validation AUC-ROC: 0.7663
# Class 6 Validation AUC-ROC: 0.7798
# Class 7 Validation AUC-ROC: 0.8013
# Epoch [11/100], Validation Loss: 1.9062, Overall Validation AUC-ROC: 0.8168
# Class 0 Validation AUC-ROC: 0.7512
# Class 1 Validation AUC-ROC: 0.8237
# Class 2 Validation AUC-ROC: 0.7583
# Class 3 Validation AUC-ROC: 0.9312
# Class 4 Validation AUC-ROC: 0.9323
# Class 5 Validation AUC-ROC: 0.7614
# Class 6 Validation AUC-ROC: 0.7739
# Class 7 Validation AUC-ROC: 0.8026
# Epoch [12/100], Validation Loss: 1.9751, Overall Validation AUC-ROC: 0.8177
# Class 0 Validation AUC-ROC: 0.7608
# Class 1 Validation AUC-ROC: 0.8202
# Class 2 Validation AUC-ROC: 0.7527
# Class 3 Validation AUC-ROC: 0.9293
# Class 4 Validation AUC-ROC: 0.9331
# Class 5 Validation AUC-ROC: 0.7632
# Class 6 Validation AUC-ROC: 0.7827
# Class 7 Validation AUC-ROC: 0.7999
# Early stopping
# Overall Test AUC-ROC: 0.8190
# Class 0 Test AUC-ROC: 0.7608
# Class 1 Test AUC-ROC: 0.8199
# Class 2 Test AUC-ROC: 0.7562
# Class 3 Test AUC-ROC: 0.9308
# Class 4 Test AUC-ROC: 0.9257
# Class 5 Test AUC-ROC: 0.7590
# Class 6 Test AUC-ROC: 0.7921
# Class 7 Test AUC-ROC: 0.8072
# Trial 3
# Using device: cuda
# Epoch [1/100], Validation Loss: 1.6244, Overall Validation AUC-ROC: 0.7973
# Class 0 Validation AUC-ROC: 0.7573
# Class 1 Validation AUC-ROC: 0.7986
# Class 2 Validation AUC-ROC: 0.7216
# Class 3 Validation AUC-ROC: 0.9217
# Class 4 Validation AUC-ROC: 0.9193
# Class 5 Validation AUC-ROC: 0.6959
# Class 6 Validation AUC-ROC: 0.7528
# Class 7 Validation AUC-ROC: 0.8112
# Epoch [2/100], Validation Loss: 1.6302, Overall Validation AUC-ROC: 0.8076
# Class 0 Validation AUC-ROC: 0.7515
# Class 1 Validation AUC-ROC: 0.8105
# Class 2 Validation AUC-ROC: 0.7295
# Class 3 Validation AUC-ROC: 0.9293
# Class 4 Validation AUC-ROC: 0.9263
# Class 5 Validation AUC-ROC: 0.7327
# Class 6 Validation AUC-ROC: 0.7691
# Class 7 Validation AUC-ROC: 0.8117
# Epoch [3/100], Validation Loss: 1.7411, Overall Validation AUC-ROC: 0.8077
# Class 0 Validation AUC-ROC: 0.7352
# Class 1 Validation AUC-ROC: 0.8071
# Class 2 Validation AUC-ROC: 0.7498
# Class 3 Validation AUC-ROC: 0.9333
# Class 4 Validation AUC-ROC: 0.9292
# Class 5 Validation AUC-ROC: 0.7331
# Class 6 Validation AUC-ROC: 0.7656
# Class 7 Validation AUC-ROC: 0.8082
# Epoch [4/100], Validation Loss: 1.6680, Overall Validation AUC-ROC: 0.8149
# Class 0 Validation AUC-ROC: 0.7473
# Class 1 Validation AUC-ROC: 0.8156
# Class 2 Validation AUC-ROC: 0.7497
# Class 3 Validation AUC-ROC: 0.9327
# Class 4 Validation AUC-ROC: 0.9304
# Class 5 Validation AUC-ROC: 0.7575
# Class 6 Validation AUC-ROC: 0.7731
# Class 7 Validation AUC-ROC: 0.8126
# Epoch [5/100], Validation Loss: 1.7558, Overall Validation AUC-ROC: 0.8128
# Class 0 Validation AUC-ROC: 0.7162
# Class 1 Validation AUC-ROC: 0.8307
# Class 2 Validation AUC-ROC: 0.7604
# Class 3 Validation AUC-ROC: 0.9340
# Class 4 Validation AUC-ROC: 0.9328
# Class 5 Validation AUC-ROC: 0.7563
# Class 6 Validation AUC-ROC: 0.7718
# Class 7 Validation AUC-ROC: 0.8005
# Epoch [6/100], Validation Loss: 1.7982, Overall Validation AUC-ROC: 0.8151
# Class 0 Validation AUC-ROC: 0.7308
# Class 1 Validation AUC-ROC: 0.8291
# Class 2 Validation AUC-ROC: 0.7594
# Class 3 Validation AUC-ROC: 0.9343
# Class 4 Validation AUC-ROC: 0.9319
# Class 5 Validation AUC-ROC: 0.7493
# Class 6 Validation AUC-ROC: 0.7759
# Class 7 Validation AUC-ROC: 0.8106
# Epoch [7/100], Validation Loss: 1.9056, Overall Validation AUC-ROC: 0.8129
# Class 0 Validation AUC-ROC: 0.7244
# Class 1 Validation AUC-ROC: 0.8226
# Class 2 Validation AUC-ROC: 0.7608
# Class 3 Validation AUC-ROC: 0.9322
# Class 4 Validation AUC-ROC: 0.9337
# Class 5 Validation AUC-ROC: 0.7521
# Class 6 Validation AUC-ROC: 0.7811
# Class 7 Validation AUC-ROC: 0.7962
# Epoch [8/100], Validation Loss: 1.9522, Overall Validation AUC-ROC: 0.8117
# Class 0 Validation AUC-ROC: 0.7289
# Class 1 Validation AUC-ROC: 0.8016
# Class 2 Validation AUC-ROC: 0.7623
# Class 3 Validation AUC-ROC: 0.9339
# Class 4 Validation AUC-ROC: 0.9330
# Class 5 Validation AUC-ROC: 0.7506
# Class 6 Validation AUC-ROC: 0.7823
# Class 7 Validation AUC-ROC: 0.8013
# Epoch [9/100], Validation Loss: 1.8874, Overall Validation AUC-ROC: 0.8141
# Class 0 Validation AUC-ROC: 0.7370
# Class 1 Validation AUC-ROC: 0.8189
# Class 2 Validation AUC-ROC: 0.7540
# Class 3 Validation AUC-ROC: 0.9331
# Class 4 Validation AUC-ROC: 0.9324
# Class 5 Validation AUC-ROC: 0.7572
# Class 6 Validation AUC-ROC: 0.7799
# Class 7 Validation AUC-ROC: 0.8002
# Epoch [10/100], Validation Loss: 1.9930, Overall Validation AUC-ROC: 0.8111
# Class 0 Validation AUC-ROC: 0.7142
# Class 1 Validation AUC-ROC: 0.8079
# Class 2 Validation AUC-ROC: 0.7580
# Class 3 Validation AUC-ROC: 0.9327
# Class 4 Validation AUC-ROC: 0.9337
# Class 5 Validation AUC-ROC: 0.7633
# Class 6 Validation AUC-ROC: 0.7824
# Class 7 Validation AUC-ROC: 0.7965
# Epoch [11/100], Validation Loss: 1.9598, Overall Validation AUC-ROC: 0.8167
# Class 0 Validation AUC-ROC: 0.7413
# Class 1 Validation AUC-ROC: 0.8210
# Class 2 Validation AUC-ROC: 0.7510
# Class 3 Validation AUC-ROC: 0.9319
# Class 4 Validation AUC-ROC: 0.9322
# Class 5 Validation AUC-ROC: 0.7648
# Class 6 Validation AUC-ROC: 0.7851
# Class 7 Validation AUC-ROC: 0.8063
# Epoch [12/100], Validation Loss: 2.0164, Overall Validation AUC-ROC: 0.8131
# Class 0 Validation AUC-ROC: 0.7336
# Class 1 Validation AUC-ROC: 0.8142
# Class 2 Validation AUC-ROC: 0.7401
# Class 3 Validation AUC-ROC: 0.9329
# Class 4 Validation AUC-ROC: 0.9324
# Class 5 Validation AUC-ROC: 0.7627
# Class 6 Validation AUC-ROC: 0.7808
# Class 7 Validation AUC-ROC: 0.8080
# Epoch [13/100], Validation Loss: 1.9876, Overall Validation AUC-ROC: 0.8160
# Class 0 Validation AUC-ROC: 0.7559
# Class 1 Validation AUC-ROC: 0.8107
# Class 2 Validation AUC-ROC: 0.7526
# Class 3 Validation AUC-ROC: 0.9335
# Class 4 Validation AUC-ROC: 0.9322
# Class 5 Validation AUC-ROC: 0.7630
# Class 6 Validation AUC-ROC: 0.7802
# Class 7 Validation AUC-ROC: 0.7999
# Epoch [14/100], Validation Loss: 2.0191, Overall Validation AUC-ROC: 0.8163
# Class 0 Validation AUC-ROC: 0.7534
# Class 1 Validation AUC-ROC: 0.8040
# Class 2 Validation AUC-ROC: 0.7597
# Class 3 Validation AUC-ROC: 0.9293
# Class 4 Validation AUC-ROC: 0.9317
# Class 5 Validation AUC-ROC: 0.7682
# Class 6 Validation AUC-ROC: 0.7841
# Class 7 Validation AUC-ROC: 0.7997
# Epoch [15/100], Validation Loss: 2.0869, Overall Validation AUC-ROC: 0.8129
# Class 0 Validation AUC-ROC: 0.7390
# Class 1 Validation AUC-ROC: 0.8097
# Class 2 Validation AUC-ROC: 0.7503
# Class 3 Validation AUC-ROC: 0.9281
# Class 4 Validation AUC-ROC: 0.9302
# Class 5 Validation AUC-ROC: 0.7639
# Class 6 Validation AUC-ROC: 0.7809
# Class 7 Validation AUC-ROC: 0.8009
# Epoch [16/100], Validation Loss: 2.0537, Overall Validation AUC-ROC: 0.8183
# Class 0 Validation AUC-ROC: 0.7684
# Class 1 Validation AUC-ROC: 0.8196
# Class 2 Validation AUC-ROC: 0.7519
# Class 3 Validation AUC-ROC: 0.9239
# Class 4 Validation AUC-ROC: 0.9314
# Class 5 Validation AUC-ROC: 0.7719
# Class 6 Validation AUC-ROC: 0.7883
# Class 7 Validation AUC-ROC: 0.7912
# Epoch [17/100], Validation Loss: 2.0576, Overall Validation AUC-ROC: 0.8158
# Class 0 Validation AUC-ROC: 0.7402
# Class 1 Validation AUC-ROC: 0.8258
# Class 2 Validation AUC-ROC: 0.7472
# Class 3 Validation AUC-ROC: 0.9286
# Class 4 Validation AUC-ROC: 0.9303
# Class 5 Validation AUC-ROC: 0.7667
# Class 6 Validation AUC-ROC: 0.7822
# Class 7 Validation AUC-ROC: 0.8053
# Epoch [18/100], Validation Loss: 2.1125, Overall Validation AUC-ROC: 0.8130
# Class 0 Validation AUC-ROC: 0.7277
# Class 1 Validation AUC-ROC: 0.8130
# Class 2 Validation AUC-ROC: 0.7489
# Class 3 Validation AUC-ROC: 0.9313
# Class 4 Validation AUC-ROC: 0.9314
# Class 5 Validation AUC-ROC: 0.7697
# Class 6 Validation AUC-ROC: 0.7859
# Class 7 Validation AUC-ROC: 0.7962
# Epoch [19/100], Validation Loss: 2.1880, Overall Validation AUC-ROC: 0.8123
# Class 0 Validation AUC-ROC: 0.7429
# Class 1 Validation AUC-ROC: 0.8067
# Class 2 Validation AUC-ROC: 0.7494
# Class 3 Validation AUC-ROC: 0.9278
# Class 4 Validation AUC-ROC: 0.9326
# Class 5 Validation AUC-ROC: 0.7659
# Class 6 Validation AUC-ROC: 0.7826
# Class 7 Validation AUC-ROC: 0.7908
# Epoch [20/100], Validation Loss: 2.1968, Overall Validation AUC-ROC: 0.8125
# Class 0 Validation AUC-ROC: 0.7367
# Class 1 Validation AUC-ROC: 0.8178
# Class 2 Validation AUC-ROC: 0.7513
# Class 3 Validation AUC-ROC: 0.9276
# Class 4 Validation AUC-ROC: 0.9317
# Class 5 Validation AUC-ROC: 0.7592
# Class 6 Validation AUC-ROC: 0.7807
# Class 7 Validation AUC-ROC: 0.7947
# Epoch [21/100], Validation Loss: 2.3121, Overall Validation AUC-ROC: 0.8101
# Class 0 Validation AUC-ROC: 0.7246
# Class 1 Validation AUC-ROC: 0.8118
# Class 2 Validation AUC-ROC: 0.7519
# Class 3 Validation AUC-ROC: 0.9299
# Class 4 Validation AUC-ROC: 0.9305
# Class 5 Validation AUC-ROC: 0.7600
# Class 6 Validation AUC-ROC: 0.7830
# Class 7 Validation AUC-ROC: 0.7887
# Early stopping
# Overall Test AUC-ROC: 0.8127
# Class 0 Test AUC-ROC: 0.7328
# Class 1 Test AUC-ROC: 0.8112
# Class 2 Test AUC-ROC: 0.7600
# Class 3 Test AUC-ROC: 0.9279
# Class 4 Test AUC-ROC: 0.9264
# Class 5 Test AUC-ROC: 0.7533
# Class 6 Test AUC-ROC: 0.7902
# Class 7 Test AUC-ROC: 0.7995

# %%
# Show AUC score for SP task
eval_results["sp_auc"]
# Out:
# 0.7519511905744471

# %%
# Show test accuracy for SR task
eval_results["sr_test_acc"]
# Out:
# 0.6713709677419355

# %%
# Show validation accuracy for SR task
eval_results["sr_validation_acc"]
# Out:
# 0.6956521739130435

# %%
# Show Top-K Hit Rate for CR task
eval_results["cr_topk_hit_rate"]
# Out:
# [0.12955922001974632,
#  0.18240535049745576,
#  0.23030967570441258,
#  0.31102329687856,
#  0.4143004291030607,
#  0.47711466165413524,
#  0.5583993126756285,
#  0.6349049707602339]

# %%
# Show overall AUC and per-ET AUC for EP task from all trials
eval_results["ep_test_auc"]
# Out:
# {'overall_mean': 0.815198977648202,
#  'overall_std': 0.0027160472182029384,
#  'per_class_mean': array([0.74505209, 0.81318325, 0.75822825, 0.9289814 , 0.9262074 ,
#         0.75893122, 0.7894433 , 0.80156491]),
#  'per_class_std': array([0.0116706 , 0.00490813, 0.00156706, 0.00126533, 0.00032441,
#         0.00461707, 0.00253323, 0.00406191]),
#  'test_auc_scores': [{'overall_test_auc': 0.8139624424198251,
#    'per_class_test_auc': array([0.74160419, 0.80841078, 0.75842525, 0.92827949, 0.92644288,
#           0.76456039, 0.78603384, 0.79794273])},
#   {'overall_test_auc': 0.8189666268221574,
#    'per_class_test_auc': array([0.76075417, 0.81993438, 0.7562181 , 0.93075787, 0.92574866,
#           0.758982  , 0.79210068, 0.80723715])},
#   {'overall_test_auc': 0.8126678637026239,
#    'per_class_test_auc': array([0.7327979 , 0.8112046 , 0.76004141, 0.92790685, 0.92643065,
#           0.75325127, 0.79019539, 0.79951485])}]}

# %% [markdown]
# ## Create DGL Graph

# %%
# Takes about 15 mins, the graph will be saved to work_folder
g = comkg.get_dgl_graph(work_folder="./experiments")
g
# Out:
# [Graph(num_nodes=1169931, num_edges=50815503,
#        ndata_schemes={'feat': Scheme(shape=(512,), dtype=torch.float32)}
#        edata_schemes={'weight': Scheme(shape=(15,), dtype=torch.float32)})]

# %%
# When call the same function again, it will load from file directly
g = comkg.get_dgl_graph(work_folder="./experiments")
g
# Out:
# [Graph(num_nodes=1169931, num_edges=50815503,
#        ndata_schemes={'feat': Scheme(shape=(512,), dtype=torch.float32)}
#        edata_schemes={'weight': Scheme(shape=(15,), dtype=torch.float32)})]

# %% [markdown]
# ## Create iGraph

# %%
g = comkg.to_igraph()
g
